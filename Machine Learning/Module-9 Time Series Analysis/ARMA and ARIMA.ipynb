# %%
#import libraries
from matplotlib import pyplot
from statsmodels.tsa.ar_model import AutoReg
from sklearn.metrics import mean_squared_error
from math import sqrt
import numpy as np
import pandas as pd

# %%
# load csv as dataset
df = pd.read_csv('daily-min-temperatures.csv')
df.head()
# Out:
#          Date  Temp
# 0  1981-01-01  20.7
# 1  1981-01-02  17.9
# 2  1981-01-03  18.8
# 3  1981-01-04  14.6
# 4  1981-01-05  15.8

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
# fit model
results_ARIMA = ARIMA(df["Temp"], order=(5,1,0))
results_ARIMA = model.fit()
# summary of fit model
print(results_ARIMA.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   Temp   No. Observations:                 3650
# Model:                 ARIMA(5, 1, 0)   Log Likelihood               -8495.813
# Date:                Mon, 01 May 2023   AIC                          17003.626
# Time:                        15:56:08   BIC                          17040.839
# Sample:                             0   HQIC                         17016.879
#                                - 3650
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.3358      0.015    -22.489      0.000      -0.365      -0.307
# ar.L2         -0.3911      0.016    -24.088      0.000      -0.423      -0.359
# ar.L3         -0.2942      0.017    -17.026      0.000      -0.328      -0.260
# ar.L4         -0.2077      0.017    -12.485      0.000      -0.240      -0.175
# ar.L5         -0.1361      0.016     -8.503      0.000      -0.167      -0.105
# sigma2         6.1628      0.138     44.620      0.000       5.892       6.433
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.03   Jarque-Bera (JB):                 7.31
# Prob(Q):                              0.31   Prob(JB):                         0.03
# Heteroskedasticity (H):               0.86   Skew:                             0.02
# Prob(H) (two-sided):                  0.01   Kurtosis:                         3.22
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
results_ARIMA.forecast(3)
# Out:
# 3650    13.240526
# 3651    13.643571
# 3652    13.765222
# Name: predicted_mean, dtype: float64

# %%
# line plot of residuals
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()

# %%
# density plot of residuals
residuals.plot(kind='kde')
pyplot.show()

# %%
# summary stats of residuals
print(residuals.describe())
# Out:
#                  0
# count  3650.000000
# mean      0.001509
# std       2.506181
# min      -8.734318
# 25%      -1.640709
# 50%       0.061717
# 75%       1.563414
# max      20.700000
